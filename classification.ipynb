# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/cancer_data.csv")

print("Rows:", df.shape)
print("Columns:", df.shape)

df.head()
# Out:
# Rows: (1500, 9)
# Columns: (1500, 9)
#    age  gender        bmi  ...  alcohol_intake  cancer_history  diagnosis
# 0   58       1  16.085313  ...        4.148219               1          1
# 1   71       0  30.828784  ...        3.519683               0          0
# 2   48       1  38.785084  ...        4.728368               0          1
# 3   34       0  30.040295  ...        2.044636               0          0
# 4   62       1  35.479721  ...        3.309849               0          1
#
# [5 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# age                  0
# gender               0
# bmi                  0
# smoking              0
# genetic_risk         0
# physical_activity    0
# alcohol_intake       0
# cancer_history       0
# diagnosis            0
# dtype: int64

# %%
X = df.drop(columns='diagnosis')
y = df['diagnosis']


from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
 from sklearn.tree import DecisionTreeClassifier
 dt = DecisionTreeClassifier()
 dt.fit(X_train, y_train)

 pred = dt.predict(X_test)
 pred

 from sklearn.metrics import classification_report
 cr = classification_report(pred,y_test)
 print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90       241
#            1       0.80      0.85      0.83       134
#
#     accuracy                           0.87       375
#    macro avg       0.86      0.87      0.86       375
# weighted avg       0.87      0.87      0.87       375

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pred_rfc = rfc.predict(X_test)
pred_rfc

rfc_cr = classification_report(pred_rfc,y_test)
print(rfc_cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94       246
#            1       0.85      0.94      0.89       129
#
#     accuracy                           0.92       375
#    macro avg       0.91      0.93      0.92       375
# weighted avg       0.93      0.92      0.92       375

# %%
from ctypes import CFUNCTYPE
arg = {
     'n_estimators':50,
    'max_features':'log2',
    'criterion':'entropy',
    'bootstrap':False,
    'max_depth':15,
    'min_samples_split':5,
    'min_samples_leaf':3
}
change_rfc = RandomForestClassifier(**arg)
change_rfc.fit(X_train, y_train)

pred_change = change_rf.predict(X_test)
pred_change

change_cr = classification_report(pred_change,y_test)
print(change_cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93       242
#            1       0.85      0.91      0.88       133
#
#     accuracy                           0.91       375
#    macro avg       0.90      0.91      0.91       375
# weighted avg       0.91      0.91      0.91       375
